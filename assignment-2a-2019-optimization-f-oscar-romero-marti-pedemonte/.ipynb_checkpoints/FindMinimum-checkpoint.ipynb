# %% [markdown]
# # Optimització - Descens del gradient

# %% [markdown]
# L’optimització matemàtica o la programació matemàtica és la selecció d’un millor element a partir d’un conjunt d’alternatives disponibles. Problemes d’optimització de tipus sorgeixen en totes les disciplines quantitatives, des de la informàtica i l’enginyeria fins a la investigació d’operacions i l’economia, i el desenvolupament de mètodes de solució ha estat d’interès en les matemàtiques durant segles.
#
# En el cas més senzill, un problema d’optimització consisteix a maximitzar o minimitzar una funció real mitjançant l’elecció sistemàtica dels valors d’entrada dins d’un conjunt permès i el càlcul del valor de la funció.
# La generalització de la teoria i tècniques d’optimització a altres formulacions constitueix una àmplia àrea de matemàtiques aplicades.
# Més generalment, l’optimització inclou trobar valors "els millors disponibles" d'alguna funció objectiva donat un domini (o entrada) definits, incloent una varietat de diferents tipus de funcions objectives i diferents tipus de dominis.
#
#
# Es pot representar un problema d'optimització de la següent manera:
#
# - Tenint en compte: una funció $f : A \to \mathbb{R}$ des d'algun conjunt $A$ als nombres reals.
# - Buscat: un element ${x}_0 \in A$ tal que $f({x}_{0}) \leq f({x})$ per a tots els ${x} \in A$ ("minimització") o tal que $f({x}_{0}) \geq f({x})$  per a tots els ${x} \in A$ ("maximització").

# %% [markdown]
# La metodologia crítica per resoldre problemes d'optimització és el **descens del gradient**.

# %% [markdown]
# **Prior:**
# S'anomena *derivada parcial* d'una funció de diverses variables a la seva derivada respecte a una d'aquestes variables, deixant les altres constants. Cada derivada indica com varia $f$ quan fem un petit canvi en la variable corresponent.
#
# El *gradient* de la funció $f(x_1, \cdots, x_n)$ és un vector format per les derivades parcials de la funció.
# Aquest dóna la direcció en la qual la funció creix més ràpidament.
#
# $$\nabla {f} = (\frac{\partial f}{\partial x_1}, \dots, \frac{\partial f}{\partial x_n})$$

# %% [markdown]
# ### 1. Cas Unidimensionals
#
# Suposem que volem calcular el nimim numèric de la següent funció unidimensional:
#
# $$ f_1(x) = x^2 $$
#
# La derivada parcial de la funcio $f$ és:
#
# $$ \frac{\partial f_1}{\partial x} = 2 x$$
#
# El primer pas que farem és visualitzar la funció i veure el comportament del gradient / derivada sobre un conjunt de punts que pertanyen el domini de la funció.

# %%
from plot_utils import *

import matplotlib.pyplot as plt
import numpy as np

if __name__ == '__main__':
    # %matplotlib inline

# %%
def f1(x):
    return x**2

def df1(x):
    return 2*x

# Function to plot
if __name__ == '__main__':
    X = np.arange(-5, 5.01, 0.25) #Utilitza np.arange() que crea un vector de forma semblant al range() que coneixem.
                                    #5.01 perquè sino no s'inclou el 5
    fig = plt.figure() #Creem un gràfic buit
    plot_1d(X, f1(X), fig) #Dibuixa la gràfica x=X, y=f(x)
    plot_gradient (X, f1(X), df1(X), fig=fig) #Dibuixa el gradient corresponent en cada punt (x,f(x)) de la gràfica anterior
    fig.gca().set_xlim(-10, 10) #Mostrar les x en l'interval (-10,10)

# %% [markdown]
# Per tant, una possible estratègia per maximitzar (*minimitzar*) la funció és reptir la següent estratègia:
#
# 1. Col·locar-se en un punt aleatori (un valor aleatori de $\mathbf{x}$)
# 2. Calcular el vector gradient.
# 3. Fer un petit pas en la direcció (*contraria*) del vector gradient: $x^{k+1} = x^{k}-\alpha^{k} \nabla f(x^{k})$
# 4. Repetir des de 2
#
# La cerca s'acabaria quan el vector gradient és zero, que vol dir que hem trobat un màxim (*mínim*). Donat que la presició flotant potser evita que arribem mai a aquest nombre, afegim dos mètodes més per acabar la cerca:
#
# 1. Si el moviment que realitzem és més petit que un epsilon ($|x^{k+1} - x^{k}| < eps$)
# 2. Si realitzem més de `max_iters` iteracions
#
# Si la funció és **unimodal** (conté un únic màxim (*mínim*)), hem trobat una la nostra solució.
# Sinó, pot ser que estem en un màxim (*mínim*) local i que sigui una solució no satisfactòria.

# %% [markdown]
# **Implementa la funció *gradient_descend_1d* seguint el procediment proposat. Durant el procés d'optimització visualitza els punts de la gràfica per on vagis passant.**
#
# Recordeu que els ordinadors generen un error numèric, per tant no heu d'igualar mai a zero, heu de fer servir una tolerància.
# Definiu també un nombre màxim d'iteracions que l'algorisme pot realitzar per arribar al punt desitjat.

# %%
def gradient_descend_1d(grad, x, alpha, eps=1e-3, max_iters=1e2):
    """
    Aquesta funció implementa l'algorisme de descens pel gradient, és a dir,
    donat un punt inicial, el gradient i el pas, intenta trobar el mínim
    de la funció seguint el gradient en direcció oposada.
    
    :param grad: Gradient de la funció
    :param x: Punt inicial
    :param alpha: Pas de cada iteració
    :param eps: Moviment mínim realitzat abans de parar
    :param max_iters: Iteracions màximes a realitzar
    :return: La funció retornarà una llista/tupla amb:
        * Una np.array de tamany [X] amb el punt inicial més els punts on s'ha mogut a cada iteració, 
            on X és el nombre d'iteracions fetes + 1
        * Punt mínim (x)
    """
    #Definim un vector points que conté el punt inicial i una primera iteració.
    points = np.array([x])
    points = np.append(points,points[-1]-alpha*grad(points[-1]))
    iters = 1 #Nombre d'iteracions
    
    while iters<max_iters and abs(points[-1]-points[-2])>eps: #Mentre no passem el nombre d'iteracions ni els últims dos punts siguin molt propers.
        points = np.append(points,points[-1]-alpha*grad(points[-1])) #Trobem un nou punt i l'afegim al final del vector
        iters += 1  #Augmentem les iteracions
    return (points, points[-1]) #En sortir del bucle retornem el vector de punts i el punt final
        #Ja sigui per arribal al màxim d'iters (que el que trobem no és el mínim) o per ser propers els punts (que retornem doncs el mínim)

if __name__ == '__main__':
    X = np.arange(-3, 3.01, 0.25)
    points, minimum = gradient_descend_1d(df1, 2, .1) #Funció gradient df1, punt inicial 2 i alpha 0.1
    fig = plt.figure()
    plot_gradient_descend_1d(f1, X, points, minimum, fig) #Amb aquesta funcio (plot_funciógradient) dibuixa la gràfica i els corresponents punts trobats
    print(minimum) #Imprimim el mínim per veure que és proper a zero tot i no ser zero com es comenta a l'enunciat.
# Out:
# 0.003868562622766814

# %% [markdown]
# Però... són totes els funcions unimodals? Obviament no.
#
# Podem tenir funcions que contenen un màxim i un mínim. Per veure com es comporten aquestes funcions **repeteix el procediment anterior amb aquesta nova funció**.
#
# $$f_2(x) = x^3 - 2x + 2$$
#
# $$ \frac{\partial f_2}{\partial x} = 3x^2 -2$$

# %%
def f2 ( x ):
    return x**3 - 2*x + 2

def df2(x):
    return 3*x**2 - 2

# %%
if __name__ == '__main__': #Anàlogament a la funció f1
    X = np.arange(-2, 2, 0.1)
    fig = plt.figure()
    fig.gca().set_xlim(-3, 3)
    plot_1d(X, f2(X), fig)
    plot_gradient(X, f2(X), df2(X), fig=fig)

# %% [markdown]
# **Començant en el punt $x=0.75$, és possible arribar a valors de $x < -1$ en 10 o menys iteracions? Fer proves demostrant que es pot, o no, arribar-hi.**
#
# **Justifica el comportament del procés d'optimització**

# %%
if __name__ == '__main__':
    X = np.arange(-20, 20, 0.1)

    # Fes les proves
    points, minimum = gradient_descend_1d(df2, 0.75, 0.6501, max_iters=10) #Sortint de 0.75, en menys de 10 iteracions
    print(minimum - np.sqrt(2/3)) #Per veure la diferència que hi ha entre el punt inicial i el zero de la funció

    fig = plt.figure() #Creem un gràfic buit
    plot_gradient_descend_1d(f2, X, points, minimum, fig) #Dibuixem la gràfica de X<->f(X) i el punts trobats amb gradient_descent
    fig.gca().set_ylim([-2, 5]) #Ajustem els intervals d'x i y per veure bé la gràfica.
    fig.gca().set_xlim([-2, 2])
# Out:
# -18.528986594724948

# %% [markdown]
# **RESPOSTA:**
#
# Es pot arribar a valors de $x<-1$ en menys de 10 iteracions. Agafant un pas gran (per exemple, 1), saltem el mínim, i arribem a una x on el gradient és més gran i de direcció oposada. Si aquest gradient és prou gran, ja haurem passat el punt $x=-1$ a la següent iteració.
# ***
# Hem comprovat que amb un pas superior a 0.6501 ja passem del $x=-1$ en menys de 10 iteracions.

# %% [markdown]
# #### Podem assegurar que sempre arribem a un minim?
#
# Suposa ara la funció
# $$
# f_{2.2}(x) = \frac{x}{1+x^2}
# $$
# amb gradient
# $$ \frac{\partial f_{2.2}}{\partial x} = \frac{1-x^2}{(1+x^2)^2}
# $$

# %%
def f2_2(x):
    return x / (1 + x**2)

def df2_2(x):
    return (1 - x**2) / (1 + x**2)**2

# %%
if __name__ == '__main__':
    X = np.arange(-20, 20, 0.01)
    fig = plt.figure()
    plot_1d(X, f2_2(X), fig) #Dibuixem la gràfica X<->f(X)

# %%
if __name__ == '__main__': #np.random.random() dóna un valor aleatori en l'interval [0,1)
    x0 = (np.random.random() - 0.5) * 10 #Donat un valor aleatori a l'interval [-5,5)
    points, minimum = gradient_descend_1d(df2_2, x0, 0.1)
    fig = plt.figure()
    plot_gradient_descend_1d(f2_2, X, points, minimum, fig)
    fig.gca().set_xlim([-10, 10])
    print(minimum)
    
#Fixem-nos que depenent l'aleatori donat els punts i el mínim trobat varien. Prova diversos cops.
# Out:
# 3.360051051523042

# %% [markdown]
# **Justifica el comportament per diferent punts d'inici. Podem arribar sempre al mínim? **

# %% [markdown]
# **RESPOSTA:**
#
# No podem assegurar que sempre arribem a un mínim. Això dependrà del punt d'inici, del pas escollit i del nombre màxim d'iteracions permeses.
# ***
# Si el punt inicial compleix $x\in(-\inf, 1)$, aleshores no arribarà al mínim si passa un de les següents casos:
#
# -Si el pas és massa gran passarà com a l'exercici anterior, que saltarà i marxarà a una zona on no es troba el mínim absolut, i on el gradient no li permet tornar a la zona del mínim.
#
# -Si el pas és massa petit no arribarà al mínim a causa del nombre màxim d'iteracions permès, que no serà suficient.
#
# En altres casos arribarà al mínim amb una tolerància definida per paràmetre a la funció.
# ***
# Si el punt inicial compleix $x\in(1, +\inf)$, aleshores la derivada sempre serà negativa (funció decreixent) i per tant sempre ens desplaçarem cap a punts més grans a l'eix de les abcisses, allunyant-nos del mínim absolut (situat a $x=-1$).

# %% [markdown]
# ### Cas N-dimensionals
#
# Podem aplicar el procediment anterior quan tenim funcions dos-dimensionals? La resposta és que sí.
#
# L'unic canvi en el procediment és que ara caldrà avançar en dues direccions.

# %% [markdown]
# Sigui la funció 2-dimensional $f_3$:
# $$ f_3(x_1, x_2) = x_1^2 + x_2^2$$
#
# i el seu gradient:
#
# $$\nabla {f_3(x_1, x_2)} =
# \left( \frac{\partial f_3}{\partial x_1}, \frac{\partial f_3}{\partial x_2}\right) =
# \left( 2 x_1, 2 x_2 \right)$$
#
# Visualitza la forma de grafica i el comportament del seu gradient.

# %%
def f3 ( x, y ):
    return x**2 + y**2

def grad_f3(x, y=None):
    return np.asarray((2 * x, 2 * y))

if __name__ == '__main__':
    # Surface to plot
    fig = plt.figure()
    X, Y, Z = generate_grid(f3, axisX=[-3,3,0.05], axisY=[-3,3,0.05]) #X,Y en el pla donat i la Z evaluant f3 en tals punts
    plot_2d(X, Y, Z, fig)

# %% [markdown]
# Per veure millor el gradient en aquest cas, podem imprimir el seu comportament en un pla.

# %%
if __name__ == '__main__':
    fig = plt.figure()
    project_gradient(f3, grad_f3, fig) #Projecta el gradient de f3 sobre el pla XY

# %% [markdown]
# Implementeu l'algorisme anterior amb el cas 2-dimensional.
#
# Recordeu amb amb la llibreria numpy podeu sumar o restar vectors, multiplicar per un escalar, etc.

# %%
def gradient_descend_2d(gradient, x, alpha=0.1, eps=1e-6, max_iter=1000, verbose=True):
    """
    Aquesta funció implementa l'algorisme de descens pel gradient en el 
    cas 2-DIMENSIONAL, és a dir, donat un punt inicial (x_0, x_1), 
    el gradient i el pas, intenta trobar el mínim de la funció seguint 
    el gradient en direcció oposada.
    
    :param grad: Gradient de la funció
    :param x: Punt inicial
    :param alpha: Pas de cada iteració
    :param eps: Moviment mínim realitzat abans de parar
    :param max_iter: Iteracions màximes a realitzar
    :param verbose: En case de ser True, la funció ha d'imprimir el nombre d'iteracions fetes
        abans de retornar
    :return: La funció retornarà una llista/tupla amb:
        * Una np.array [X] amb el punt inicial més els punts on s'ha mogut a cada iteració, 
            on X és el nombre d'iteracions fetes + 1
        * Punt mínim
    """
    points = np.array([x]) #Definim un vector de punts que conté el punt inicial de dues components (x,y)
    points = np.append(points, [points[-1]-alpha*gradient(points[-1][0], points[-1][1])], axis=0) #Calculem el següent punt
        #IMPORTANT!! Cal escriure [] en l'element que s'afegeix i axis = 0, sinó dóna error.
    iters = 1
    
    while iters<max_iter and np.linalg.norm(points[-1]-points[-2])>eps: #Igual que en una dimensió
        points = np.append(points, [points[-1]-alpha*gradient(points[-1][0], points[-1][1])], axis=0)
        iters += 1
    if verbose:
        print(iters)
    return (points, points[-1])

if __name__ == '__main__':
    x0 = np.asarray([1, 1])
    points, minimum = gradient_descend_2d(grad_f3, x0)
    print(minimum)
# Out:
# 58
# [2.39452428e-06 2.39452428e-06]

# %%
if __name__ == '__main__':
    print ("Minimum: ", np.round(minimum,3)) #Arrodonim el nombre trobat, que ha de ser zero si està bé la funció anterior

    fig = plt.figure()
    X, Y, _ = generate_grid(f3)
    plot_gradient_descend_2d(f3, grad_f3, X, Y, points, minimum, fig) #Dibuixem tot plegat sobre el pla XY
# Out:
# Minimum:  [0. 0.]

# %% [markdown]
# Considera ara la funció
# $$f_4(x_1, x_2) = 100(x_1^2 + x_2^2)$$
#
# amb gradient
#
# $$\nabla {f_4(x_1, x_2)} =
# \left( \frac{\partial f_4}{\partial x_1}, \frac{\partial f_4}{\partial x_2}\right) =
# \left( 200 x_1, 200 x_2 \right)$$
#
# **Fent servir `gradient_descend_2d`, podeu trobar el mínim de les funcions $f_3$ i $f_4$ amb el següents paràmetres?**
#
# * $\alpha$ igual en les dues crides, es pot modificar
# * $x=(1, 1)$ en les dues crides
# * `max_iter=100` en les dues crides
# * `eps=1e-6` en les dues crides
#
# **Justifica perque són capaços, o no, de trobar el mínim amb aquest paràmetres. Quines dificultats presenta?**

# %%
def f4(x, y):
    return 100 * (x**2 + y**2)

def grad_f4(x, y):
    return np.asarray((200 * x, 200 * y))

# %%
if __name__ == '__main__':
    x0 = np.asarray((1, 1))
    alpha = 0.009
    points_f3, minimum_f3 = gradient_descend_2d(grad_f3, x0, alpha=alpha, max_iter=100, eps=1e-6)
    points_f4, minimum_f4 = gradient_descend_2d(grad_f4, x0, alpha=alpha, max_iter=100, eps=1e-6)
# Out:
# 100
# 68

# %%
if __name__ == '__main__':
    fig = plt.figure()
    X, Y, _ = generate_grid(f3)
    plot_gradient_descend_2d(f3, grad_f3, X, Y, points_f3, minimum_f3, fig)
    print(minimum_f3)
# Out:
# [0.16261057 0.16261057]

# %%
if __name__ == '__main__':
    fig = plt.figure()
    X, Y, _ = generate_grid(f4)
    plot_gradient_descend_2d(f4, grad_f4, X, Y, points_f4, minimum_f4, fig)
    print(minimum_f4)
# Out:
# [2.57110087e-07 2.57110087e-07]

# %% [markdown]
# **RESPOSTA:**
#
# En primer lloc, observem que $\alpha < 0.01$ per la segona funció, ja que sinó eternament em mouré del punt (1,1) al (-1,-1) de forma periòdica. Per un $\alpha <0.01$, per exemple, $\alpha = 0.0095$, la segona funció ja arriba al mínim (arriba a (2.6e-5, 2.7e-5)). No obstant, com que el pas ha de ser menor que 0.01, a la primera funció no hi arribarà mai amb bona precisió a causa del limitat nombre d'iteracions permès: com que té un pas massa petit, no hi acaba arribant mai amb 100 iteracions. Per exemple, per $\alpha = 0.0097$, per la primera funció arribem a (0.14,0.14), i a la segona a (0.002,0.002).
#
# És a dir, que per una banda hem de tenir un pas petit perquè la segona funció no s'envagi cap a l'infinit (ja que per $\alpha > 0.01$, el gradient a cada pas va augmentant indefinidament), i per l'altra el pas ha de ser prou gran com per permetre arribar en menys de 100 iteracions la primera funció al mínim. Veiem que la intersecció d'aquestes dues condicions és nul·la, i per tant no podem trobar una $\alpha$ que ens permeti trobar el mínim de les dues funcions amb una bona precisió simultàniament.
#
# En el gràfic construït a la cel·la següent hi representem la primera coordenada del mínim trobat, per cada funció, en funció del paràmetre $\alpha$ donat. Noteu que només representem la primera coordenada, ja que al partir d'un punt simètric (1,1) i al tractar-se de funcions simètriques ($f(x,y) = f(y,x)$), el gradient també ho serà i per tant tots els punts de la successió també seràn simètrics.

# %%
if __name__ == '__main__':
    x1 = np.array([])
    x2 = np.array([])
    x = np.array([])
    for i in range(2000):
        alpha = 0.008 + i*0.00001
        x = np.append(x, alpha)
        points_f3, minimum_f3 = gradient_descend_2d(grad_f3, x0, alpha=alpha, max_iter=100, eps=1e-6, verbose=False)
        points_f4, minimum_f4 = gradient_descend_2d(grad_f4, x0, alpha=alpha, max_iter=100, eps=1e-6, verbose=False)
        x1 = np.append(x1, minimum_f3[0])
        x2 = np.append(x2, minimum_f4[0])

# %%
if __name__ == '__main__':

    fig = plt.figure() #Creem un gràfic buit
    plt.plot(x, x1, 'b-', label='f3 minimum') #Dibuixa la gràfica x=X, y=f(x)
    plt.plot(x, x2, 'r-', label='f4 minimum') #Dibuixa la gràfica x=X, y=f(x)
    fig.gca().set_xlim(0.008, 0.014)
    fig.gca().set_ylim(1e-4, 10)
    plt.yscale('log')
    plt.grid()
    plt.legend(loc=2)
    plt.title('Minimum of functions f3 and f4 vs alpha')
    plt.xlabel('alpha', fontsize=15)
    plt.ylabel('$1^{st}$ coordinate minimum', fontsize=15)
    plt.gcf().set_size_inches((12,6))

# %% [markdown]
# Com podem observar al gràfic anterior, el mínim de la funció f3 es trobarà amb més precisió quan $\alpha$ sigui gran (per exemple, amb una precisió per sota de 0.1 quan $\alpha$ sigui aproximadament 0.0115). En canvi, per la f4, el mínim es trobarà amb més precisió quan alpha sigui més petit (i no minúscul, ja que sinó tampoc es mourà de lloc si el pas és massa petit), entre 0.005 i 0.009 és la regió asequada per a una gran precisió del mínim de f4.

# %% [markdown]
# ## Temps de convergència
#
# Observa ara la següent funció, anomenada funció de **Rosenbrock**.
#
# $$ f(x_1, x_2) = (a - x_1)^2 + b (x_2 - x_1^2)^2$$
#
# **El mínim d'aquesta funció es troba al punt: $(x_1, x_2) = (a, a^{2})$.**

# %%
A_ROS = 1

def f_ros(x, y, a=A_ROS, b=10):
    return (a-x)**2 + b*(y-x**2)**2

def grad_f_ros(x, y, a=A_ROS, b=10):
    return np.asarray((-2*a + 4*b*x**3 - 4*b*x*y + 2*x, 2*b*(y-x**2)))

# %%
if __name__ == '__main__':
    # Surface to plot
    fig = plt.figure()
    X, Y, Z = generate_grid(f_ros)
    plot_2d(X, Y, Z, fig) #Dibuixa en 3D

# %%
if __name__ == '__main__':
    fig = plt.figure()
    project_gradient(f_ros, grad_f_ros, fig)
    plt.scatter(A_ROS, A_ROS**2, marker='x', color='r', s=200) #Marca el mínim amb una X vermella.

# %% [markdown]
# Aquesta funció té un mínim molt pla, la pendent és pràcticament nula al sel voltat, pel que els mètodes iteratius tarden molt a trobar el mínim

# %%
if __name__ == '__main__':
    fig = plt.figure()
    x0 = np.asarray((-1.5, 1.5))
    points, minimum = gradient_descend_2d(grad_f_ros, x0, alpha=0.01, max_iter=10000)
    X, Y, _ = generate_grid(f_ros)
    plot_gradient_descend_2d(f_ros, grad_f_ros, X, Y, points, minimum, fig)
    print(minimum) #Dibuixa de nou tot al pla XY, gradient i punts trobats
# Out:
# 2109
# [0.99988876 0.99977307]

# %% [markdown]
# ## Trobant el pas òptim
#
# Una possibilitat per fer menys iteracions i accelerar la convergència és trobant el valor de $\alpha$ automàticament a cada pas, és a dir aquella $\alpha$ que fa mínim el valor de $f$.
#
# L'algorisme és tal que:
#
# 1. Col·locar-se en un punt aleatori (un valor aleatori de $\mathbf{x}$)
# 2. Calcular el vector gradient
# 3. $\alpha = 10$
# 4. Calcular $x^{k+1} = x^{k}-\alpha \nabla f(x^{k})$
# 5. Si $f(x^{k+1}) > f(x^{k})$, $\alpha = \alpha / 2$, descartar $x^{k+1}$ i tornar al pas 4
# 6. En cas contrari, moure's a $x^{k+1}$ i repetir des de 2

# %%
def gradient_descend_2d_auto(f, gradient, x, eps=1e-6, max_iter=1000, initial_alpha=10, verbose=True):
    """
    Aquesta funció implementa l'algorisme de descens pel gradient en el 
    cas 2-DIMENSIONAL, és a dir, donat un punt inicial (x_0, x_1), 
    el gradient i el pas, intenta trobar el mínim de la funció seguint 
    el gradient en direcció oposada.
    
    :param f: Funció a minimitzar
    :param grad: Gradient de la funció
    :param x: Punt inicial
    :param eps: Moviment mínim realitzat abans de parar
    :param max_iter: Iteracions màximes a realitzar
    :param initial_alpha: Pas inicial a cada iteració, corresponent al punt 3 anterior
    :param verbose: En case de ser True, la funció ha d'imprimir el nombre d'iteracions fetes
        abans de retornar
    :return: La funció retornarà una llista/tupla amb:
        * Una np.array [X, 2] amb el punt inicial més els punts on s'ha mogut a cada iteració, 
            on X és el nombre d'iteracions fetes + 1
        * El punt mínim
    """
    point = x #Point serà l'últim punt trobat i next_point el següent que calculem a partir de point
    points = np.array([point]) #Definim un vector amb els punts trobats, per començar el punt inicial
    next_point = x + eps #Per poder entrar al bucle
    iters = 0
    
    while iters<max_iter and np.linalg.norm(point-next_point)>eps:
        alpha = 10. #Definim alpha 10
        point = points[-1]
        next_point = point-alpha*gradient(point[0], point[1]) #Calculem un next_point
        while f(next_point[0], next_point[1]) > f(point[0], point[1]): #Si pasa la condició ens el quedem, sino canviem l'alpha i trobem un altre next_point
            alpha /= 2.
            next_point = point-alpha*gradient(point[0], point[1])
        points = np.append(points, [next_point], axis=0) #Quan sortim del segon bucle, guardem next_point i iterem de nou
        iters += 1
    if verbose:
        print(iters)
        
    return (points, points[-1]) #Retornem els punts i l'últim trobat (el mínim si hem arribat per iteracions)

# %%
if __name__ == '__main__':
    fig = plt.figure()
    x0 = np.asarray((-1.5, 1.5))
    points, minimum = gradient_descend_2d_auto(f_ros, grad_f_ros, x0, max_iter=10000)
    X, Y, _ = generate_grid(f_ros)
    plot_gradient_descend_2d(f_ros, grad_f_ros, X, Y, points, minimum, fig)
    print(minimum)
# Out:
# 1002
# [0.99996455 0.99992681]

# %%
if __name__ == '__main__':
    # %timeit gradient_descend_2d(grad_f_ros, x0, alpha=0.01, max_iter=10000, verbose=False)
# Out:
# 34.7 ms ± 223 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
if __name__ == '__main__':
    # %timeit gradient_descend_2d_auto(f_ros, grad_f_ros, x0, max_iter=10000, verbose=False)
# Out:
# 95.1 ms ± 146 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
